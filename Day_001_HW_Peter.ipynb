# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.732

# %%
def mean_squared_error(y,yp):

    mse = MSE = sum((y - yp)*(y - yp)) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 190.981
# The Mean absolute error is 10.732

# %%
"""
Google Landmark Recognition Challenge

1.對愛出遊的人很有貢獻
2.格式化表單
3.非結構化的圖像
4.正確率                             
"""
# Out:
# '\nGoogle Landmark Recognition Challenge\n\n1.對愛出遊的人很有貢獻\n2.格式化表單\n3.非結構化的圖像\n4.正確率                             \n'

# %%
"""

1.調整班表達到需求與供給平衡，假設目前尖峰時間車隊無法獲得所有客人，離峰時間有閒置人員
2.據點載客情況與司機實際載人時間,格式化表單
3.結構化的表格
4.將離峰時間的人員數量降低，尖峰時間的人員增加，看是否在成本不變的情況下增加業績

"""
# Out:
# '\n\n1.調整班表達到需求與供給平衡，假設目前尖峰時間車隊無法獲得所有客人，離峰時間有閒置人員\n2.據點載客情況與司機實際載人時間,格式化表單\n3.結構化的表格\n4.將離峰時間的人員數量降低，尖峰時間的人員增加，看是否在成本不變的情況下增加業績\n\n'
